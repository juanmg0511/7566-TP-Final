# %% [markdown]
# # 1. Introduction + Set-up
#
# Machine learning has a phenomenal range of applications, including in health and diagnostics. This tutorial will explain the complete pipeline from loading data to predicting results, and it will explain how to build an X-ray image classification model from scratch to predict whether an X-ray scan shows presence of pneumonia. This is especially useful during these current times as COVID-19 is known to cause pneumonia.
#
# This tutorial will explain how to utilize TPUs efficiently, load in image data, build and train a convolution neural network, finetune and regularize the model, and predict results. Data augmentation is not included in the model because X-ray scans are only taken in a specific orientation, and variations such as flips and rotations will not exist in real X-ray images. For a tutorial on image data augmentation, check out this [tutorial](https://www.kaggle.com/amyjang/tensorflow-data-augmentation-efficientnet).
#
# Run the following cell to load the necessary packages. Make sure to change the Accelerator on the right to `TPU`.

# %%
import re
import os
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

try:
    tpu = tf.distribute.cluster_resolver.TPUClusterResolver()
    print('Device:', tpu.master())
    tf.config.experimental_connect_to_cluster(tpu)
    tf.tpu.experimental.initialize_tpu_system(tpu)
    strategy = tf.distribute.experimental.TPUStrategy(tpu)
except:
    strategy = tf.distribute.get_strategy()
print('Number of replicas:', strategy.num_replicas_in_sync)
    
print(tf.__version__)
# Out:
# Number of replicas: 1
# 2.9.1

# %% [markdown]
# We need a Google Cloud link to our data to load the data using a TPU. While we're at it, we instantiate constant variables. It is generally better practice to use constant variables instead of hard-coding numbers.

# %%
AUTOTUNE = tf.data.experimental.AUTOTUNE
BATCH_SIZE = 16 * strategy.num_replicas_in_sync
IMAGE_SIZE = [180, 180]
EPOCHS = 25

# %% [markdown]
# # 2. Load the data
#
# The Chest X-ray data we are using from [*Cell*](https://www.kaggle.com/paultimothymooney/chest-xray-pneumonia) divides the data into train, val, and test files. There are only 16 files in the validation folder, and we would prefer to have a less extreme division between the training and the validation set. We will append the validation files and create a new split that resembes the standard 80:20 division instead.

# %%
filenames = tf.io.gfile.glob(str('../chest_xray/train/*/*'))
filenames.extend(tf.io.gfile.glob(str('../chest_xray/val/*/*')))

train_filenames, val_filenames = train_test_split(filenames, test_size=0.2)

# %% [markdown]
# Run the following cell to see how many healthy/normal chest X-rays we have and how many pneumonia chest X-rays we have.

# %%
COUNT_NORMAL = len([filename for filename in train_filenames if "NORMAL" in filename])
print("Normal images count in training set: " + str(COUNT_NORMAL))

COUNT_PNEUMONIA = len([filename for filename in train_filenames if "PNEUMONIA" in filename])
print("Pneumonia images count in training set: " + str(COUNT_PNEUMONIA))
# Out:
# Normal images count in training set: 1089
# Pneumonia images count in training set: 3096

# %% [markdown]
# Notice that the there are way more images that are classified as pneumonia than normal. This shows that we have a imbalance in our data. We will correct for this imbalance later on in our notebook.

# %%
train_list_ds = tf.data.Dataset.from_tensor_slices(train_filenames)
val_list_ds = tf.data.Dataset.from_tensor_slices(val_filenames)

for f in train_list_ds.take(5):
    print(f.numpy())
# Out:
# b'../chest_xray/train/PNEUMONIA/person595_virus_1147.jpeg'
# b'../chest_xray/train/PNEUMONIA/person435_bacteria_1879.jpeg'
# b'../chest_xray/train/NORMAL/IM-0525-0001.jpeg'
# b'../chest_xray/train/NORMAL/NORMAL2-IM-1020-0001-0001.jpeg'
# b'../chest_xray/train/PNEUMONIA/person67_bacteria_331.jpeg'
# 2022-11-21 17:47:08.731997: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# Run the following cell to see how many images we have in our training dataset and how many images we have in our validation set. Verify that the ratio of images is 80:20.

# %%
TRAIN_IMG_COUNT = tf.data.experimental.cardinality(train_list_ds).numpy()
print("Training images count: " + str(TRAIN_IMG_COUNT))

VAL_IMG_COUNT = tf.data.experimental.cardinality(val_list_ds).numpy()
print("Validating images count: " + str(VAL_IMG_COUNT))
# Out:
# Training images count: 4185
# Validating images count: 1047

# %% [markdown]
# As expected, we have two labels for our images.

# %%
CLASS_NAMES = np.array([str(tf.strings.split(item, os.path.sep)[-1].numpy())[2:-1]
                        for item in tf.io.gfile.glob(str("../chest_xray/train/*"))])
CLASS_NAMES
# Out:
# array(['PNEUMONIA', 'NORMAL'], dtype='<U9')

# %% [markdown]
# Currently our dataset is just a list of filenames. We want to map each filename to the corresponding (image, label) pair. The following methods will help us do that.
#
# As we only have two labels, we will rewrite the label so that `1` or `True` indicates pneumonia and `0` or `False` indicates normal.

# %%
def get_label(file_path):
    # convert the path to a list of path components
    parts = tf.strings.split(file_path, os.path.sep)
    # The second to last is the class-directory
    return parts[-2] == "PNEUMONIA"

# %% [markdown]
# The images originally have values that range from [0, 255]. CNNs work better with smaller numbers so we will scale this down.

# %%
def decode_img(img):
  # convert the compressed string to a 3D uint8 tensor
  img = tf.image.decode_jpeg(img, channels=3)
  # Use `convert_image_dtype` to convert to floats in the [0,1] range.
  img = tf.image.convert_image_dtype(img, tf.float32)
  # resize the image to the desired size.
  return tf.image.resize(img, IMAGE_SIZE)

# %%
def process_path(file_path):
    label = get_label(file_path)
    # load the raw data from the file as a string
    img = tf.io.read_file(file_path)
    img = decode_img(img)
    return img, label

# %%
train_ds = train_list_ds.map(process_path, num_parallel_calls=AUTOTUNE)

val_ds = val_list_ds.map(process_path, num_parallel_calls=AUTOTUNE)

# %% [markdown]
# Let's visualize the shape of an (image, label) pair.

# %%
for image, label in train_ds.take(1):
    print("Image shape: ", image.numpy().shape)
    print("Label: ", label.numpy())
# Out:
# Image shape:  (180, 180, 3)
# Label:  True

# %% [markdown]
# Load and format the test data as well.

# %%
test_list_ds = tf.data.Dataset.list_files(str('../chest_xray/test/*/*'))
TEST_IMAGE_COUNT = tf.data.experimental.cardinality(test_list_ds).numpy()
test_ds = test_list_ds.map(process_path, num_parallel_calls=AUTOTUNE)
test_ds = test_ds.batch(BATCH_SIZE)

TEST_IMAGE_COUNT
# Out:
# 624

# %% [markdown]
# # 3. Visualize the dataset
#
# First, let's use buffered prefetching so we can yield data from disk without having I/O become blocking.

# %%
def prepare_for_training(ds, cache=True, shuffle_buffer_size=1000):
    # This is a small dataset, only load it once, and keep it in memory.
    # use `.cache(filename)` to cache preprocessing work for datasets that don't
    # fit in memory.
    if cache:
        if isinstance(cache, str):
            ds = ds.cache(cache)
        else:
            ds = ds.cache()

    ds = ds.shuffle(buffer_size=shuffle_buffer_size)

    # Repeat forever
    ds = ds.repeat()

    ds = ds.batch(BATCH_SIZE)

    # `prefetch` lets the dataset fetch batches in the background while the model
    # is training.
    ds = ds.prefetch(buffer_size=AUTOTUNE)

    return ds

# %% [markdown]
# Call the next batch iteration of the training data.

# %%
train_ds = prepare_for_training(train_ds)
val_ds = prepare_for_training(val_ds)

image_batch, label_batch = next(iter(train_ds))
# Out:
# 2022-11-21 17:48:07.230223: W tensorflow/core/kernels/data/cache_dataset_ops.cc:856] The calling iterator did not fully read the dataset being cached. In order to avoid unexpected truncation of the dataset, the partially cached contents of the dataset  will be discarded. This can happen if you have an input pipeline similar to `dataset.cache().take(k).repeat()`. You should use `dataset.take(k).cache().repeat()` instead.

# %% [markdown]
# Define the method to show the images in the batch.

# %%
def show_batch(image_batch, label_batch):
    plt.figure(figsize=(10,10))
    for n in range(16):
        ax = plt.subplot(5,5,n+1)
        plt.imshow(image_batch[n])
        if label_batch[n]:
            plt.title("PNEUMONIA")
        else:
            plt.title("NORMAL")
        plt.axis("off")

# %% [markdown]
# As the method takes in numpy arrays as its parameters, call the numpy function on the batches to return the tensor in numpy array form.

# %%
show_batch(image_batch.numpy(), label_batch.numpy())

# %% [markdown]
# # 4. Build the CNN
#
# To make our model more modular and easier to understand, let's define some blocks. As we're building a convolution neural network, we'll create a convolution block and a dense layer block.
#
# The architecture for this CNN has been inspired by this [article](https://towardsdatascience.com/deep-learning-for-detecting-pneumonia-from-x-ray-images-fc9a3d9fdba8).

# %%
def conv_block(filters):
    block = tf.keras.Sequential([
        tf.keras.layers.SeparableConv2D(filters, 3, activation='relu', padding='same'),
        tf.keras.layers.SeparableConv2D(filters, 3, activation='relu', padding='same'),
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.MaxPool2D()
    ]
    )
    
    return block

# %%
def dense_block(units, dropout_rate):
    block = tf.keras.Sequential([
        tf.keras.layers.Dense(units, activation='relu'),
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.Dropout(dropout_rate)
    ])
    
    return block

# %% [markdown]
# The following method will define the function to build our model for us. The Dropout layers are important as they "drop out," hence the name, certain nodes to reduce the likelikhood of the model overfitting. We want to end the model with a Dense layer of one node, as this will be the output that determines if an X-ray shows an image of pneumonia.

# %%
def build_model():
    model = tf.keras.Sequential([
        tf.keras.Input(shape=(IMAGE_SIZE[0], IMAGE_SIZE[1], 3)),
        
        tf.keras.layers.Conv2D(16, 3, activation='relu', padding='same'),
        tf.keras.layers.Conv2D(16, 3, activation='relu', padding='same'),
        tf.keras.layers.MaxPool2D(),
        
        conv_block(32),
        conv_block(64),
        
        conv_block(128),
        tf.keras.layers.Dropout(0.2),
        
        conv_block(256),
        tf.keras.layers.Dropout(0.2),
        
        tf.keras.layers.Flatten(),
        dense_block(512, 0.7),
        dense_block(128, 0.5),
        dense_block(64, 0.3),
        
        tf.keras.layers.Dense(1, activation='sigmoid')
    ])
    
    return model

# %% [markdown]
# # 5. Correct for data imbalance
#
# We saw earlier in this notebook that the data was imbalanced, with more images classified as pneumonia than normal. We will correct for that in this following section.

# %%
initial_bias = np.log([COUNT_PNEUMONIA/COUNT_NORMAL])
initial_bias
# Out:
# array([1.04485111])

# %%
weight_for_0 = (1 / COUNT_NORMAL)*(TRAIN_IMG_COUNT)/2.0 
weight_for_1 = (1 / COUNT_PNEUMONIA)*(TRAIN_IMG_COUNT)/2.0

class_weight = {0: weight_for_0, 1: weight_for_1}

print('Weight for class 0: {:.2f}'.format(weight_for_0))
print('Weight for class 1: {:.2f}'.format(weight_for_1))
# Out:
# Weight for class 0: 1.92
# Weight for class 1: 0.68

# %% [markdown]
# The weight for class `0` (Normal) is a lot higher than the weight for class `1` (Pneumonia). Because there are less normal images, each normal image will be weighted more to balance the data as the CNN works best when the training data is balanced.

# %% [markdown]
# # 6. Train the model
#
# Since there are only two possible labels for the image, we will be using the `binary_crossentropy` loss. When we fit the model, identify the class weights. Because we are using a TPU, training will be relatively quick.
#
# For our metrics, we want to include precision and recall as they will provide use with a more informed picture of how good our model is. Accuracy tells us what fractions are the labels are correct. Since our data is not balanced, accuracy might give a skewed sense of a good model (i.e. a model that always predicts PNEUMONIA will be 74% accurate but is not a good model).
#
# Precision is the number of true positives (TP) over the sum of TP and false positives (FP). It shows what fraction of labeled positives are actually correct.
#
# Recall is the number of TP over the sum of TP and false negatves (FN). It shows what fraction of actual positives are correct.

# %%
with strategy.scope():
    model = build_model()

    METRICS = [
        'accuracy',
        tf.keras.metrics.Precision(name='precision'),
        tf.keras.metrics.Recall(name='recall')
    ]
    
    model.compile(
        optimizer='adam',
        loss='binary_crossentropy',
        metrics=METRICS
    )

# %% [markdown]
# From exploring the data and the model, I noticed that the training for the model has a slow start. However, after 25 epochs, the model slowly starts to converge.

# %%
history = model.fit(
    train_ds,
    steps_per_epoch=TRAIN_IMG_COUNT // BATCH_SIZE,
    epochs=EPOCHS,
    validation_data=val_ds,
    validation_steps=VAL_IMG_COUNT // BATCH_SIZE,
    class_weight=class_weight,
)
# Out:
# Epoch 1/25
# 261/261 [==============================] - 190s 688ms/step - loss: 0.3995 - accuracy: 0.7933 - precision: 0.9477 - recall: 0.7628 - val_loss: 0.6448 - val_accuracy: 0.7510 - val_precision: 0.7510 - val_recall: 1.0000
# Epoch 2/25
# 261/261 [==============================] - 153s 586ms/step - loss: 0.2280 - accuracy: 0.9124 - precision: 0.9716 - recall: 0.9081 - val_loss: 1.0623 - val_accuracy: 0.7519 - val_precision: 0.7519 - val_recall: 1.0000
# Epoch 3/25
# 261/261 [==============================] - 153s 585ms/step - loss: 0.1856 - accuracy: 0.9301 - precision: 0.9827 - recall: 0.9217 - val_loss: 0.1301 - val_accuracy: 0.9587 - val_precision: 0.9694 - val_recall: 0.9756
# Epoch 4/25
# 261/261 [==============================] - 155s 595ms/step - loss: 0.1736 - accuracy: 0.9344 - precision: 0.9802 - recall: 0.9301 - val_loss: 1.0708 - val_accuracy: 0.7558 - val_precision: 0.7553 - val_recall: 1.0000
# Epoch 5/25
# 261/261 [==============================] - 164s 628ms/step - loss: 0.1771 - accuracy: 0.9313 - precision: 0.9785 - recall: 0.9276 - val_loss: 0.1931 - val_accuracy: 0.9308 - val_precision: 0.9930 - val_recall: 0.9141
# Epoch 6/25
# 261/261 [==============================] - 174s 665ms/step - loss: 0.1567 - accuracy: 0.9380 - precision: 0.9816 - recall: 0.9336 - val_loss: 0.0892 - val_accuracy: 0.9663 - val_precision: 0.9686 - val_recall: 0.9872
# Epoch 7/25
# 261/261 [==============================] - 177s 679ms/step - loss: 0.1376 - accuracy: 0.9490 - precision: 0.9845 - recall: 0.9459 - val_loss: 0.7970 - val_accuracy: 0.7423 - val_precision: 1.0000 - val_recall: 0.6569
# Epoch 8/25
# 261/261 [==============================] - 175s 671ms/step - loss: 0.1197 - accuracy: 0.9531 - precision: 0.9879 - recall: 0.9482 - val_loss: 0.2144 - val_accuracy: 0.9404 - val_precision: 0.9986 - val_recall: 0.9219
# Epoch 9/25
# 261/261 [==============================] - 171s 657ms/step - loss: 0.1278 - accuracy: 0.9540 - precision: 0.9846 - recall: 0.9528 - val_loss: 0.2083 - val_accuracy: 0.9096 - val_precision: 0.8945 - val_recall: 0.9974
# Epoch 10/25
# 261/261 [==============================] - 161s 619ms/step - loss: 0.1186 - accuracy: 0.9569 - precision: 0.9883 - recall: 0.9531 - val_loss: 0.0931 - val_accuracy: 0.9644 - val_precision: 0.9883 - val_recall: 0.9643
# Epoch 11/25
# 261/261 [==============================] - 155s 595ms/step - loss: 0.1390 - accuracy: 0.9480 - precision: 0.9855 - recall: 0.9437 - val_loss: 0.1034 - val_accuracy: 0.9625 - val_precision: 0.9960 - val_recall: 0.9540
# Epoch 12/25
# 261/261 [==============================] - 154s 588ms/step - loss: 0.1204 - accuracy: 0.9543 - precision: 0.9885 - recall: 0.9491 - val_loss: 0.1079 - val_accuracy: 0.9587 - val_precision: 0.9881 - val_recall: 0.9566
# Epoch 13/25
# 261/261 [==============================] - 153s 585ms/step - loss: 0.1177 - accuracy: 0.9593 - precision: 0.9903 - recall: 0.9544 - val_loss: 0.0782 - val_accuracy: 0.9673 - val_precision: 0.9795 - val_recall: 0.9770
# Epoch 14/25
# 261/261 [==============================] - 152s 584ms/step - loss: 0.1216 - accuracy: 0.9521 - precision: 0.9872 - recall: 0.9475 - val_loss: 0.0687 - val_accuracy: 0.9740 - val_precision: 0.9809 - val_recall: 0.9847
# Epoch 15/25
# 261/261 [==============================] - 152s 582ms/step - loss: 0.0780 - accuracy: 0.9720 - precision: 0.9943 - recall: 0.9676 - val_loss: 0.1000 - val_accuracy: 0.9673 - val_precision: 0.9973 - val_recall: 0.9591
# Epoch 16/25
# 261/261 [==============================] - 153s 587ms/step - loss: 0.0917 - accuracy: 0.9626 - precision: 0.9917 - recall: 0.9578 - val_loss: 0.3167 - val_accuracy: 0.8894 - val_precision: 1.0000 - val_recall: 0.8526
# Epoch 17/25
# 261/261 [==============================] - 153s 584ms/step - loss: 0.0861 - accuracy: 0.9662 - precision: 0.9920 - recall: 0.9620 - val_loss: 0.0919 - val_accuracy: 0.9750 - val_precision: 0.9714 - val_recall: 0.9962
# Epoch 18/25
# 261/261 [==============================] - 153s 586ms/step - loss: 0.0804 - accuracy: 0.9722 - precision: 0.9914 - recall: 0.9708 - val_loss: 0.1243 - val_accuracy: 0.9490 - val_precision: 0.9461 - val_recall: 0.9885
# Epoch 19/25
# 261/261 [==============================] - 153s 587ms/step - loss: 0.0902 - accuracy: 0.9634 - precision: 0.9907 - recall: 0.9596 - val_loss: 0.0899 - val_accuracy: 0.9673 - val_precision: 0.9973 - val_recall: 0.9591
# Epoch 20/25
# 261/261 [==============================] - 153s 588ms/step - loss: 0.0979 - accuracy: 0.9634 - precision: 0.9917 - recall: 0.9587 - val_loss: 0.0817 - val_accuracy: 0.9712 - val_precision: 0.9896 - val_recall: 0.9718
# Epoch 21/25
# 261/261 [==============================] - 154s 591ms/step - loss: 0.0786 - accuracy: 0.9689 - precision: 0.9926 - recall: 0.9649 - val_loss: 0.0997 - val_accuracy: 0.9673 - val_precision: 0.9832 - val_recall: 0.9731
# Epoch 22/25
# 261/261 [==============================] - 154s 592ms/step - loss: 0.1084 - accuracy: 0.9622 - precision: 0.9877 - recall: 0.9609 - val_loss: 0.2795 - val_accuracy: 0.8885 - val_precision: 0.9926 - val_recall: 0.8581
# Epoch 23/25
# 261/261 [==============================] - 309s 1s/step - loss: 0.1040 - accuracy: 0.9622 - precision: 0.9913 - recall: 0.9573 - val_loss: 0.1004 - val_accuracy: 0.9663 - val_precision: 0.9921 - val_recall: 0.9629
# Epoch 24/25
# 261/261 [==============================] - 162s 622ms/step - loss: 0.0702 - accuracy: 0.9737 - precision: 0.9943 - recall: 0.9698 - val_loss: 0.0656 - val_accuracy: 0.9769 - val_precision: 0.9846 - val_recall: 0.9846
# Epoch 25/25
# 261/261 [==============================] - 149s 571ms/step - loss: 0.0706 - accuracy: 0.9722 - precision: 0.9927 - recall: 0.9695 - val_loss: 0.1209 - val_accuracy: 0.9587 - val_precision: 1.0000 - val_recall: 0.9449

# %% [markdown]
# # 7. Finetune the model
#
# Finetuning is an art when it comes to Machine Learning, and there are many ways to adjust the model in efforts to improve it. Finetuning is beyond the scope of this notebook, but check out this [article](https://www.pyimagesearch.com/2019/06/03/fine-tuning-with-keras-and-deep-learning/) for more information.
#
# For our purposes, we'll use Keras callbacks to further finetune our model. The checkpoint callback saves the best weights of the model, so next time we want to use the model, we do not have to spend time training it. The early stopping callback stops the training process when the model starts becoming stagnant, or even worse, when the model starts overfitting. Since we set `restore_best_weights` to `True`, the returned model at the end of the training process will be the model with the best weights (i.e. low loss and high accuracy).

# %%
checkpoint_cb = tf.keras.callbacks.ModelCheckpoint("xray_model.h5",
                                                    save_best_only=True)

early_stopping_cb = tf.keras.callbacks.EarlyStopping(patience=10,
                                                     restore_best_weights=True)

# %% [markdown]
# We also want to finetune our learning rate. Too high of a learning rate will cause the model to diverge. Too small of a learning rate will cause the model to be too slow. We implement the exponential learning rate scheduling method below.

# %%
def exponential_decay(lr0, s):
    def exponential_decay_fn(epoch):
        return lr0 * 0.1 **(epoch / s)
    return exponential_decay_fn

exponential_decay_fn = exponential_decay(0.01, 20)

lr_scheduler = tf.keras.callbacks.LearningRateScheduler(exponential_decay_fn)

# %%
history = model.fit(
    train_ds,
    steps_per_epoch=TRAIN_IMG_COUNT // BATCH_SIZE,
    epochs=100,
    validation_data=val_ds,
    validation_steps=VAL_IMG_COUNT // BATCH_SIZE,
    class_weight=class_weight,
    callbacks=[checkpoint_cb, early_stopping_cb, lr_scheduler]
)
# Out:
# Epoch 1/100
# 261/261 [==============================] - 173s 662ms/step - loss: 0.3290 - accuracy: 0.8635 - precision: 0.9522 - recall: 0.8585 - val_loss: 0.4386 - val_accuracy: 0.8663 - val_precision: 0.9763 - val_recall: 0.8427 - lr: 0.0100
# Epoch 2/100
# 261/261 [==============================] - 165s 632ms/step - loss: 0.2182 - accuracy: 0.9124 - precision: 0.9713 - recall: 0.9084 - val_loss: 0.1217 - val_accuracy: 0.9538 - val_precision: 0.9693 - val_recall: 0.9693 - lr: 0.0089
# Epoch 3/100
# 261/261 [==============================] - 160s 613ms/step - loss: 0.2263 - accuracy: 0.9116 - precision: 0.9709 - recall: 0.9077 - val_loss: 0.1493 - val_accuracy: 0.9413 - val_precision: 0.9852 - val_recall: 0.9360 - lr: 0.0079
# Epoch 4/100
# 261/261 [==============================] - 173s 664ms/step - loss: 0.1857 - accuracy: 0.9284 - precision: 0.9788 - recall: 0.9234 - val_loss: 0.1578 - val_accuracy: 0.9433 - val_precision: 0.9725 - val_recall: 0.9513 - lr: 0.0071
# Epoch 5/100
# 261/261 [==============================] - 170s 653ms/step - loss: 0.1650 - accuracy: 0.9382 - precision: 0.9819 - recall: 0.9335 - val_loss: 0.1130 - val_accuracy: 0.9538 - val_precision: 0.9633 - val_recall: 0.9756 - lr: 0.0063
# Epoch 6/100
# 261/261 [==============================] - 174s 665ms/step - loss: 0.1757 - accuracy: 0.9306 - precision: 0.9798 - recall: 0.9253 - val_loss: 0.1568 - val_accuracy: 0.9423 - val_precision: 0.9639 - val_recall: 0.9590 - lr: 0.0056
# Epoch 7/100
# 261/261 [==============================] - 179s 688ms/step - loss: 0.1916 - accuracy: 0.9303 - precision: 0.9794 - recall: 0.9251 - val_loss: 0.1324 - val_accuracy: 0.9471 - val_precision: 0.9481 - val_recall: 0.9834 - lr: 0.0050
# Epoch 8/100
# 261/261 [==============================] - 170s 652ms/step - loss: 0.1658 - accuracy: 0.9363 - precision: 0.9833 - recall: 0.9300 - val_loss: 0.1111 - val_accuracy: 0.9548 - val_precision: 0.9791 - val_recall: 0.9603 - lr: 0.0045
# Epoch 9/100
# 261/261 [==============================] - 165s 632ms/step - loss: 0.1541 - accuracy: 0.9418 - precision: 0.9846 - recall: 0.9358 - val_loss: 0.1132 - val_accuracy: 0.9587 - val_precision: 0.9881 - val_recall: 0.9565 - lr: 0.0040
# Epoch 10/100
# 261/261 [==============================] - 164s 627ms/step - loss: 0.1296 - accuracy: 0.9492 - precision: 0.9858 - recall: 0.9450 - val_loss: 0.7651 - val_accuracy: 0.9471 - val_precision: 0.9631 - val_recall: 0.9668 - lr: 0.0035
# Epoch 11/100
# 261/261 [==============================] - 162s 622ms/step - loss: 0.1366 - accuracy: 0.9507 - precision: 0.9868 - recall: 0.9460 - val_loss: 0.6849 - val_accuracy: 0.7538 - val_precision: 0.7536 - val_recall: 1.0000 - lr: 0.0032
# Epoch 12/100
# 261/261 [==============================] - 162s 620ms/step - loss: 0.1220 - accuracy: 0.9545 - precision: 0.9889 - recall: 0.9491 - val_loss: 0.0969 - val_accuracy: 0.9596 - val_precision: 0.9805 - val_recall: 0.9655 - lr: 0.0028
# Epoch 13/100
# 261/261 [==============================] - 156s 598ms/step - loss: 0.0885 - accuracy: 0.9684 - precision: 0.9937 - recall: 0.9634 - val_loss: 0.1170 - val_accuracy: 0.9567 - val_precision: 0.9933 - val_recall: 0.9488 - lr: 0.0025
# Epoch 14/100
# 261/261 [==============================] - 155s 596ms/step - loss: 0.1058 - accuracy: 0.9612 - precision: 0.9886 - recall: 0.9586 - val_loss: 0.0891 - val_accuracy: 0.9654 - val_precision: 0.9782 - val_recall: 0.9757 - lr: 0.0022
# Epoch 15/100
# 261/261 [==============================] - 154s 588ms/step - loss: 0.0939 - accuracy: 0.9650 - precision: 0.9923 - recall: 0.9601 - val_loss: 0.1065 - val_accuracy: 0.9587 - val_precision: 0.9894 - val_recall: 0.9552 - lr: 0.0020
# Epoch 16/100
# 261/261 [==============================] - 151s 580ms/step - loss: 0.1007 - accuracy: 0.9650 - precision: 0.9907 - recall: 0.9619 - val_loss: 0.1033 - val_accuracy: 0.9567 - val_precision: 0.9842 - val_recall: 0.9577 - lr: 0.0018
# Epoch 17/100
# 261/261 [==============================] - 151s 579ms/step - loss: 0.1000 - accuracy: 0.9670 - precision: 0.9884 - recall: 0.9667 - val_loss: 0.1046 - val_accuracy: 0.9558 - val_precision: 0.9792 - val_recall: 0.9618 - lr: 0.0016
# Epoch 18/100
# 261/261 [==============================] - 152s 581ms/step - loss: 0.0885 - accuracy: 0.9693 - precision: 0.9917 - recall: 0.9666 - val_loss: 0.0890 - val_accuracy: 0.9663 - val_precision: 0.9820 - val_recall: 0.9732 - lr: 0.0014
# Epoch 19/100
# 261/261 [==============================] - 151s 580ms/step - loss: 0.0751 - accuracy: 0.9765 - precision: 0.9941 - recall: 0.9742 - val_loss: 0.0876 - val_accuracy: 0.9692 - val_precision: 0.9820 - val_recall: 0.9770 - lr: 0.0013
# Epoch 20/100
# 261/261 [==============================] - 153s 587ms/step - loss: 0.0732 - accuracy: 0.9758 - precision: 0.9940 - recall: 0.9731 - val_loss: 0.0843 - val_accuracy: 0.9673 - val_precision: 0.9857 - val_recall: 0.9706 - lr: 0.0011
# Epoch 21/100
# 261/261 [==============================] - 281s 1s/step - loss: 0.0688 - accuracy: 0.9787 - precision: 0.9944 - recall: 0.9767 - val_loss: 0.0829 - val_accuracy: 0.9673 - val_precision: 0.9819 - val_recall: 0.9744 - lr: 0.0010
# Epoch 22/100
# 261/261 [==============================] - 1170s 4s/step - loss: 0.0633 - accuracy: 0.9787 - precision: 0.9925 - recall: 0.9787 - val_loss: 0.0863 - val_accuracy: 0.9683 - val_precision: 0.9832 - val_recall: 0.9744 - lr: 8.9125e-04
# Epoch 23/100
# 261/261 [==============================] - 151s 578ms/step - loss: 0.0698 - accuracy: 0.9746 - precision: 0.9917 - recall: 0.9736 - val_loss: 0.0886 - val_accuracy: 0.9692 - val_precision: 0.9883 - val_recall: 0.9706 - lr: 7.9433e-04
# Epoch 24/100
# 261/261 [==============================] - 164s 628ms/step - loss: 0.0763 - accuracy: 0.9749 - precision: 0.9931 - recall: 0.9729 - val_loss: 0.0817 - val_accuracy: 0.9712 - val_precision: 0.9821 - val_recall: 0.9796 - lr: 7.0795e-04
# Epoch 25/100
# 261/261 [==============================] - 164s 629ms/step - loss: 0.0614 - accuracy: 0.9782 - precision: 0.9928 - recall: 0.9776 - val_loss: 0.0813 - val_accuracy: 0.9673 - val_precision: 0.9819 - val_recall: 0.9744 - lr: 6.3096e-04
# Epoch 26/100
# 261/261 [==============================] - 151s 581ms/step - loss: 0.0592 - accuracy: 0.9808 - precision: 0.9954 - recall: 0.9786 - val_loss: 0.0818 - val_accuracy: 0.9692 - val_precision: 0.9845 - val_recall: 0.9744 - lr: 5.6234e-04
# Epoch 27/100
# 261/261 [==============================] - 175s 669ms/step - loss: 0.0674 - accuracy: 0.9770 - precision: 0.9941 - recall: 0.9748 - val_loss: 0.0799 - val_accuracy: 0.9692 - val_precision: 0.9832 - val_recall: 0.9757 - lr: 5.0119e-04
# Epoch 28/100
# 261/261 [==============================] - 190s 728ms/step - loss: 0.0614 - accuracy: 0.9796 - precision: 0.9954 - recall: 0.9769 - val_loss: 0.0820 - val_accuracy: 0.9683 - val_precision: 0.9832 - val_recall: 0.9744 - lr: 4.4668e-04
# Epoch 29/100
# 261/261 [==============================] - 182s 696ms/step - loss: 0.0654 - accuracy: 0.9782 - precision: 0.9957 - recall: 0.9748 - val_loss: 0.0962 - val_accuracy: 0.9644 - val_precision: 0.9895 - val_recall: 0.9628 - lr: 3.9811e-04
# Epoch 30/100
# 261/261 [==============================] - 182s 699ms/step - loss: 0.0589 - accuracy: 0.9806 - precision: 0.9957 - recall: 0.9780 - val_loss: 0.0837 - val_accuracy: 0.9683 - val_precision: 0.9845 - val_recall: 0.9732 - lr: 3.5481e-04
# Epoch 31/100
# 261/261 [==============================] - 195s 749ms/step - loss: 0.0574 - accuracy: 0.9808 - precision: 0.9938 - recall: 0.9803 - val_loss: 0.0775 - val_accuracy: 0.9683 - val_precision: 0.9832 - val_recall: 0.9744 - lr: 3.1623e-04
# Epoch 32/100
# 261/261 [==============================] - 202s 775ms/step - loss: 0.0494 - accuracy: 0.9825 - precision: 0.9967 - recall: 0.9798 - val_loss: 0.0805 - val_accuracy: 0.9721 - val_precision: 0.9833 - val_recall: 0.9795 - lr: 2.8184e-04
# Epoch 33/100
# 261/261 [==============================] - 207s 795ms/step - loss: 0.0511 - accuracy: 0.9849 - precision: 0.9977 - recall: 0.9818 - val_loss: 0.0818 - val_accuracy: 0.9750 - val_precision: 0.9834 - val_recall: 0.9834 - lr: 2.5119e-04
# Epoch 34/100
# 261/261 [==============================] - 212s 813ms/step - loss: 0.0496 - accuracy: 0.9828 - precision: 0.9954 - recall: 0.9813 - val_loss: 0.0823 - val_accuracy: 0.9731 - val_precision: 0.9834 - val_recall: 0.9809 - lr: 2.2387e-04
# Epoch 35/100
# 261/261 [==============================] - 173s 663ms/step - loss: 0.0563 - accuracy: 0.9813 - precision: 0.9947 - recall: 0.9799 - val_loss: 0.0867 - val_accuracy: 0.9692 - val_precision: 0.9845 - val_recall: 0.9744 - lr: 1.9953e-04
# Epoch 36/100
# 261/261 [==============================] - 168s 642ms/step - loss: 0.0576 - accuracy: 0.9813 - precision: 0.9947 - recall: 0.9799 - val_loss: 0.0851 - val_accuracy: 0.9712 - val_precision: 0.9833 - val_recall: 0.9783 - lr: 1.7783e-04
# Epoch 37/100
# 261/261 [==============================] - 191s 730ms/step - loss: 0.0512 - accuracy: 0.9816 - precision: 0.9960 - recall: 0.9789 - val_loss: 0.0830 - val_accuracy: 0.9731 - val_precision: 0.9833 - val_recall: 0.9808 - lr: 1.5849e-04
# Epoch 38/100
# 261/261 [==============================] - 165s 633ms/step - loss: 0.0428 - accuracy: 0.9859 - precision: 0.9967 - recall: 0.9842 - val_loss: 0.0856 - val_accuracy: 0.9712 - val_precision: 0.9833 - val_recall: 0.9783 - lr: 1.4125e-04
# Epoch 39/100
# 261/261 [==============================] - 157s 602ms/step - loss: 0.0572 - accuracy: 0.9820 - precision: 0.9957 - recall: 0.9800 - val_loss: 0.0837 - val_accuracy: 0.9692 - val_precision: 0.9833 - val_recall: 0.9757 - lr: 1.2589e-04
# Epoch 40/100
# 261/261 [==============================] - 157s 600ms/step - loss: 0.0421 - accuracy: 0.9847 - precision: 0.9977 - recall: 0.9814 - val_loss: 0.0833 - val_accuracy: 0.9721 - val_precision: 0.9833 - val_recall: 0.9795 - lr: 1.1220e-04
# Epoch 41/100
# 261/261 [==============================] - 155s 594ms/step - loss: 0.0543 - accuracy: 0.9818 - precision: 0.9951 - recall: 0.9803 - val_loss: 0.0822 - val_accuracy: 0.9702 - val_precision: 0.9833 - val_recall: 0.9770 - lr: 1.0000e-04

# %% [markdown]
# # 8. Visualizing model performance
#
# Let's plot the model accuracy and loss for the training and the validating set. These plots show the accuracy and loss values for the second round of training. Since we initially trained the model with 30 epochs, these would be epochs 31-45. Note that no random seed is specified for this notebook. For your notebook, there might be slight variance.

# %%
fig, ax = plt.subplots(1, 4, figsize=(20, 3))
ax = ax.ravel()

for i, met in enumerate(['precision', 'recall', 'accuracy', 'loss']):
    ax[i].plot(history.history[met])
    ax[i].plot(history.history['val_' + met])
    ax[i].set_title('Model {}'.format(met))
    ax[i].set_xlabel('epochs')
    ax[i].set_ylabel(met)
    ax[i].legend(['train', 'val'])

# %% [markdown]
# We see that the accuracy for our model is around 98%. Finetune the model further to see if we can achieve a higher accuracy.

# %% [markdown]
# # 9. Predict and evaluate results
#
# Let's evaluate the model on our test data!

# %%
loss, acc, prec, rec = model.evaluate(test_ds)
# Out:
# 39/39 [==============================] - 11s 280ms/step - loss: 0.7647 - accuracy: 0.7901 - precision: 0.7554 - recall: 0.9821

# %% [markdown]
# We see that our accuracy on our test data is 83%, which is lower than the accuracy for our validating set. This may indicate overfitting. Try finetuning the model further to decrease overfitting to the training and validation sets.
#
# Our recall is greater than our precision, indicating that almost all pneumonia images are correctly identified but some normal images are falsely identified. We should aim to increase our precision.
