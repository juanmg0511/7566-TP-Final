# %% [markdown]
# # 75.68 - Sistemas de Soporte para Celdas de Producción Flexibles
# ## Trabajo Práctico: análisis y detección de neumonía en radiografías
#
# Artículos:
# https://www.kaggle.com/code/madz2000/pneumonia-detection-using-cnn-92-6-accuracy/
# https://towardsdatascience.com/exploratory-data-analysis-ideas-for-image-classification-d3fc6bbfb2d2/
# https://towardsdatascience.com/train-validation-and-test-sets-72cb40cba9e7
#
# Dataset:
# https://data.mendeley.com/datasets/rscbjbr9sj/3
#
# - 79979 - Gonzalez, Juan Manuel (juagonzalez@fi.uba.ar)
# - 89180 - Contini, Agustín José María (acontini@fi.uba.ar)
#
# 2C2022

# %% [markdown]
# ## 1. Setup inicial
#
# Importación de bibliotecas y configuraciones básicas.

# %%
import pandas as pd

# Configuración de parametros de Pandas para mejor visualización
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
pd.set_option('display.max_colwidth', None)
pd.set_option('display.precision', 3)
pd.set_option('plotting.backend', 'matplotlib') 
pd.options.mode.chained_assignment = None

# En produccion eliminar, se incluye por informacion
print(f'Pandas Version: {pd.__version__}')
# Out:
# Pandas Version: 1.5.1

# %%
import numpy as np

np.set_printoptions(suppress=True)

# En produccion eliminar, se incluye por informacion
print(f'Numpy version: {np.__version__}')
# Out:
# Numpy version: 1.21.5

# %%
# En produccion eliminar, se incluye por informacion
import matplotlib
print(f'Matplotlib version: {matplotlib.__version__}')

import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams["figure.figsize"] = (15,7)
# Out:
# Matplotlib version: 3.6.2

# %%
# Importación del resto de las librerías utilizadas
from platform import python_version
import cv2
import os
import seaborn as sns
import keras
import tensorflow as tf
from math import ceil
from keras.models import Sequential
from keras.layers import Dense, Conv2D , MaxPool2D , Flatten , Dropout , BatchNormalization
from keras.preprocessing.image import ImageDataGenerator
from keras.utils.vis_utils import plot_model
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report,confusion_matrix
from sklearn.decomposition import PCA
from keras.callbacks import ReduceLROnPlateau

# %%
# Supresión de warnings
import warnings
warnings.filterwarnings("ignore")

# %%
print('\nLibrerías base__________________________________')
print('Python'.ljust(15) + ' : ' + str(python_version()))
print('Numpy'.ljust(15) + ' : ' + str(np.__version__))
print('Pandas'.ljust(15) + ' : ' + str(pd.__version__)) 
print('Tensorflow'.ljust(15) + ' : ' + str(tf.__version__))
print('\nLibrerías jupyter_______________________________')
bfJuppyter = !jupyter --version
for bfPackages in bfJuppyter:
    if bfPackages.count('Selected Jupyter')==0:
        arPackages = bfPackages.split(':')
        print(arPackages[0].strip().capitalize().ljust(15) + ' :' + arPackages[1]) 
print('________________________________________________\n')
# Out:
# Librerías base__________________________________
# Python          : 3.9.15
# Numpy           : 1.21.5
# Pandas          : 1.5.1
# Tensorflow      : 2.8.0
#
# Librerías jupyter_______________________________
# Ipython         : 8.6.0
# Ipykernel       : 5.5.5
# Ipywidgets      : 8.0.2
# Jupyter_client  : 7.3.4
# Jupyter_core    : 4.11.2
# Jupyter_server  : 1.23.2
# Jupyterlab      : 3.5.0
# Nbclient        : 0.7.0
# Nbconvert       : 7.2.5
# Nbformat        : 5.7.0
# Notebook        : 6.5.2
# Qtconsole       : not installed
# Traitlets       : 5.5.0
# ________________________________________________

# %% [markdown]
# ## 2. Descripción del dataset y carga de los datos

# %% [markdown]
# ### 2.1 Dataset utilizado
#
# El dataset utilizado se encuentra disponible en Mendeley, en su versión 3:
#
# **Large Dataset of Labeled Optical Coherence Tomography (OCT) and Chest X-Ray Images**
# *Kermany D, Goldbaum M, Cai W et al. Identifying Medical Diagnoses and Treatable Diseases by Image-Based Deep Learning. Cell. 2018; 172(5):1122-1131. doi:10.1016/j.cell.2018.02.010*
#
# Este dataset contiene miles de tomografías de coherencia óptica (OCT) y placas de rayos-x de tórax (frente) que han sido validadas. La fuente son la University of California San Diego, y el Guangzhou Women and Children's Medical Center. Las imágenes se encuentran nombradas como (enfermedad)-(ID de paciente aleatorio)-(número de imagen del paciente).
#
# En particular, para este trabajo, tomaremos únicamente las placas de tórax (suman 5856 imágenes), que han sido clasificadas entre normales, neumonía de origen viral y neumonía de origen bacteriano.
#
# Se trabajará solamente con dos clases: **NORMAL** y **NEUMONIA**.

# %% [markdown]
# ### 2.2. Carga de los datos
#
# El dataset de radiografías de tórax que hemos utilizado ya divide los archivos en train, val y test, con muy pocos archivos en el directorio de validación. Para este trabajo, uniremos todos los arhivos y crearemos un split 80:20 estándar, luego de realizar el análisis exploratorio.

# %%
# Definición de labels, y tamaño de imagen a utilizar
labels = ['NORMAL', 'PNEUMONIA']
img_size = 150

# %%
# Leemos los datos de las 3 carpetas proporcionadas en el dataset
# Las imágenes las almacenamos como matrices de enteros: cada posición representa
# el valor de intensidad del píxel en escala de grises [0, 255]
def get_data(data_dir):
    data = [] 
    for label in labels: 
        path = os.path.join(data_dir, label)
        # class_num = identificación de targets o clases (0 es normal y 1 es neumonía)
        class_num = labels.index(label)
        for img in os.listdir(path):
            try:
                img_arr = cv2.imread(os.path.join(path, img), cv2.IMREAD_GRAYSCALE)
                # Las imágenes son resampleadas al tamaño especificado
                resized_arr = cv2.resize(img_arr, (img_size, img_size))
                data.append([resized_arr, class_num])
            except Exception as e:
                print(e)
    return np.array(data, dtype=object)

train_dir = get_data('../chest_xray/train')
test_dir = get_data('../chest_xray/test')
val_dir = get_data('../chest_xray/val')

# %%
# Vemos la longitud de cada uno
print('Cantidad de imágenes en directorio "train": ' + str(len(train_dir)))
print('Cantidad de imágenes en directorio "test": ' + str(len(test_dir)))
print('Cantidad de imágenes en directorio "val": ' + str(len(val_dir)))
# Out:
# Cantidad de imágenes en directorio "train": 5216
# Cantidad de imágenes en directorio "test": 624
# Cantidad de imágenes en directorio "val": 16

# %% [markdown]
# ## 3. Visualización de los Datos
#
# Si bien contamos con un dataset de imágenes, realizaremos un breve análisis exploratorio para entender las características generales de los datos.

# %%
# Separamos las imágenes de cada clase en dos listas, para el directorio "train"
normal_images = []
pneumonia_images = []
l = []

for i in train_dir:
    if i[1] == 0:
        normal_images.append(i[0])
        l.append("Normal")
    else:
        pneumonia_images.append(i[0])
        l.append("Pneumonia")

print('Cantidad de imágenes con clase 0 (NORMAL): ' + str(len(normal_images)))
print('Cantidad de imágenes con clase 1 (PNEUMONIA): ' + str(len(pneumonia_images)))
# Out:
# Cantidad de imágenes con clase 0 (NORMAL): 1341
# Cantidad de imágenes con clase 1 (PNEUMONIA): 3875

# %% [markdown]
# ### 3.1. Distribución de clases

# %%
# Investigamos la distribución de las imágenes en el set de entrenamiento
sns.histplot(l)
# Out:
# <AxesSubplot: ylabel='Count'>

# %% [markdown]
# Hay mas imágenes clasificadas como neumonía que normales, por lo que tenemos un dataset desbalanceado.

# %% [markdown]
# ### 3.2. Visualización de imágenes de ejemplo

# %%
# Mostramos un batch de imagenes del dataset
img_to_show = 25

def show_batch(normal_images, pneumonia_images):

    plt.figure(figsize=(10,10))
    for n in range(int(img_to_show/2)):
        ax = plt.subplot(5,5,n+1)
        plt.imshow(normal_images[n], cmap='gray')
        plt.title("NORMAL")
        plt.axis("off")
    for n in range(int(img_to_show/2), img_to_show):
        ax = plt.subplot(5,5,n+1)
        plt.imshow(pneumonia_images[n], cmap='gray')
        plt.title("PNEUMONIA")
        plt.axis("off")
        
show_batch(normal_images, pneumonia_images)

# %% [markdown]
# ### 3.3. Imágenes media y de desviación estándar
#
# Vamos a calcular la imagen media y de desviación estándar para cada clase. Para lograrlo, trabajamos con los valores de intensidad de cada píxel en todas las observaciones.

# %%
# Calculamos la media y desviación standard de ambas clases
def find_mean_img(full_mat):
    mean_img = np.mean(full_mat, axis = 0)
    return mean_img

def find_std_img(full_mat):
    std_img = np.std(full_mat, axis = 0)
    return std_img

norm_mean = find_mean_img(normal_images)
pneu_mean = find_mean_img(pneumonia_images)
norm_std = find_std_img(normal_images)
pneu_std = find_std_img(pneumonia_images)

images = [[norm_mean, 'Mean NORMAL'], [pneu_mean, 'Mean PNEUMONIA'], [norm_std, 'Std NORMAL'], [pneu_std, 'Std PNEUMONIA']]

plt.figure(figsize=(10,10))
for n in range(len(images)):
    ax = plt.subplot(5,5,n+1)
    plt.imshow(images[n][0], cmap='gray')
    plt.title(images[n][1])
    plt.axis('off')

# %% [markdown]
# Las medias nos muestran que las placas clasificadas como neumonía tienden a mostrar mayor obstrucción en la zona del pecho. Asismimo, podemos ver en las imágenes de desviación estándar que la mayor variabilidad (zonas claras) se da en la zona de los pulmones.
#
# ### 3.4. Diferencia con contraste entre las imágenes medias
#
# Una prueba interesante consiste en calcular la diferencia, aplicando un contraste, entre las imágenes medias de cada clase, calculadas en la sección anterior. En este caso podemos ver que las mayores diferencias (zonas rojas) se dan en la zona de los pulmones.

# %%
# Difrencia con contraste para ambos caos
contrast_mean = pneu_mean - norm_mean

plt.figure(figsize=(2,2))
plt.imshow(contrast_mean, cmap='bwr')
plt.title('Diferencia entre imágenes medias')
plt.axis('off')
plt.show()

# %% [markdown]
# ### 3.5. Autoimágenes
#
# Finalmente, podemos utilizar una técnica de reducción de dimensiones, como por ejemplo PCA (principal component analysis) para visualizar los componentes que mejor describen cada clase. Estas "autoimágenes", que son en realidad los autovectores de nuestra matriz, pueden ser transformados a una matriz y ploteados. Esta técnica se utilizó por primera vez para reconocimiento facial.
#
# Mostraremos aquí los componentes que describen un 70% de variablidad para cada clase.

# %%
def eigenimages(full_mat, title, n_comp = 0.7, size = (64, 64)):
    pca = PCA(n_components = n_comp, whiten = True)
    pca.fit(full_mat)
    print('Number of PC (' + str(title) + '): ' + str(pca.n_components_))
    return pca

np_normal_images = np.array(normal_images)
nsamples, nx, ny = np_normal_images.shape
d2_normal_images = np_normal_images.reshape((nsamples,nx*ny))
d2_normal_images_ein = eigenimages(d2_normal_images, 'NORMAL')

np_pneumonia_images = np.array(pneumonia_images)
nsamples, nx, ny = np_pneumonia_images.shape
d2_pneumonia_images = np_pneumonia_images.reshape((nsamples,nx*ny))
d2_pneumonia_images = eigenimages(d2_pneumonia_images, 'PNEUMONIA')
# Out:
# Number of PC (NORMAL): 27
# Number of PC (PNEUMONIA): 14

# %%
def plot_pca(pca, title):
    n = pca.n_components_
    fig = plt.figure(figsize=(8, 8))
    r = int(n**.5)
    c = ceil(n/ r)
    plt.title(title)
    plt.axis('off')
    for i in range(n):
        ax = fig.add_subplot(r, c, i + 1, xticks = [], yticks = [])
        ax.imshow(pca.components_[i].reshape((img_size, img_size)), cmap='gray')
    plt.show()
    
plot_pca(d2_normal_images_ein, 'NORMAL')
plot_pca(d2_pneumonia_images, 'PNEUMONIA')

# %% [markdown]
# Podemos observar que las autoimágenes de las placas sanas muestran mucha más definicion alrededor de las costillas y los organos, comparados con la clase perteneciente a observaciones clasificacadas como neumonía.

# %% [markdown]
# ## 4. Preparación de los Datos
#
# En esta sección nos encargamos de preparar los datos para el proceso de entrenamiento, realizando diversas transformaciones y operaciones.

# %% [markdown]
# ### 4.1. Unificación y Split  80/20
#
# Realizamos la unión de los archivos y luego hacemos el split mediante sklearn. Acto seguido, preparamos series para utilizar con la red neuronal, separando los targets de las imágenes.

# %%
# Unimos los 3 directorios y hacemos el split mediante sklearn
train_test_val = [*train_dir, *test_dir, *val_dir]
train_temp, test = train_test_split(train_test_val, test_size=0.2)

# Separamos de train el set de validación
train, val = train_test_split(train_temp, test_size=0.1)

# %%
# Vemos la longitud de cada uno
print('Cantidad de imágenes en set "train": ' + str(len(train)))
print('Cantidad de imágenes en set "test": ' + str(len(test)))
print('Cantidad de imágenes en set "val": ' + str(len(val)))
# Out:
# Cantidad de imágenes en set "train": 4215
# Cantidad de imágenes en set "test": 1172
# Cantidad de imágenes en set "val": 469

# %%
# Separamos las imágenes de los valores de los targets:
# x = imagenes
# y = targets o clases (0 es normal y 1 es neumonía)

x_train = []
y_train = []

x_val = []
y_val = []

x_test = []
y_test = []

for feature, label in train:
    x_train.append(feature)
    y_train.append(label)

for feature, label in test:
    x_test.append(feature)
    y_test.append(label)
    
for feature, label in val:
    x_val.append(feature)
    y_val.append(label)

# %% [markdown]
# ### 4.2. Normalización y aumento de los datos
#
# Normalizamos los valores de intensidad de los píxeles, entre 0 y 1, para su uso con la red neuronal.
#
# Usamos real-time data generator de tensor flow, para generar imágenes y prevenir el overfitting al utilizar las variaciones en forma automática en cada epoch. Introducimos zoom, rotaciones y desplazamientos en ancho y alto solamente, dado que las otras opciones alteran las placas de una manera que harían que no fueran analizables (por ejemplo un flip o imagen especular).

# %%
# Normalizamos los valores de intensidad de los píxeles, entre 0 y 1, para su uso con la red neuronal
x_train = np.array(x_train)/255
x_val = np.array(x_val)/255
x_test = np.array(x_test)/255

# %%
# Aumento de los datos
x_train = x_train.reshape(-1, img_size, img_size, 1)
y_train = np.array(y_train)

x_val = x_val.reshape(-1, img_size, img_size, 1)
y_val = np.array(y_val)

x_test = x_test.reshape(-1, img_size, img_size, 1)
y_test = np.array(y_test)

datagen = ImageDataGenerator(
        featurewise_center=False,
        samplewise_center=False,
        featurewise_std_normalization=False,
        samplewise_std_normalization=False,
        zca_whitening=False,
        rotation_range = 30,
        zoom_range = 0.2,
        width_shift_range=0.1,
        height_shift_range=0.1,
        horizontal_flip = False,
        vertical_flip=False)

datagen.fit(x_train)

# %% [markdown]
# ### 4.3. Corrección de desbalance en el dataset

# %%
# Contamos en el set de train, cuantos casos hay de cada clase
count_normal = 0
count_pneumonia = 0

for i in train:
    if i[1] == 0:
        count_normal = count_normal + 1
    else:
        count_pneumonia = count_pneumonia + 1
        
print('Cantidad de imágenes con clase 0 (NORMAL): ' + str(count_normal))
print('Cantidad de imágenes con clase 1 (PNEUMONIA): ' + str(count_pneumonia))
# Out:
# Cantidad de imágenes con clase 0 (NORMAL): 1126
# Cantidad de imágenes con clase 1 (PNEUMONIA): 3089

# %%
initial_bias = np.log(count_pneumonia/count_normal)
print('Bias inicial: ' + str(initial_bias))
# Out:
# Bias inicial: 1.009175884218946

# %%
weight_for_0 = (1/len(normal_images))*(len(train))/2.0 
weight_for_1 = (1/len(pneumonia_images))*(len(train))/2.0

class_weight = {0: weight_for_0, 1: weight_for_1}

print('Peso para la clase 0 (NORMAL): {:.2f}'.format(weight_for_0))
print('Peso para la clase 1 (PNEUMONIA): {:.2f}'.format(weight_for_1))
# Out:
# Peso para la clase 0 (NORMAL): 1.57
# Peso para la clase 1 (PNEUMONIA): 0.54

# %% [markdown]
# ## 5. Construcción del modelo y entrenamiento
#
# Construimos una red neuronal profunda mediante la definición de un modelo secuencial implementado en Keras.

# %% [markdown]
# ### 5.1. Construcción del modelo
#
# Contamos como input con una capa de Conv2D de Keras, y como salida una capa densa de 1D, ya que tenemos que clasificar 2 posibles categorías. Las capas ocultas que forman esta red profunda están capas de convolucion, mormalización, maxpooling y dropout intercaladas, estas últimas a fin de prevenir overfitting. Como algoritmo de optimización utilizamos "rmsprop", y la función de loss es "binary_crossentropy." Las métricas utilizadas son "accuracy", "precision" y "recall".

# %%
# Construimos el modelo de la CNN a utilizar
model = Sequential()
model.add(Conv2D(32 , (3,3) , strides = 1 , padding = 'same' , activation = 'relu' , input_shape = (img_size,img_size,1)))
model.add(BatchNormalization())
model.add(MaxPool2D((2,2) , strides = 2 , padding = 'same'))
model.add(Conv2D(64 , (3,3) , strides = 1 , padding = 'same' , activation = 'relu'))
model.add(Dropout(0.1))
model.add(BatchNormalization())
model.add(MaxPool2D((2,2) , strides = 2 , padding = 'same'))
model.add(Conv2D(64 , (3,3) , strides = 1 , padding = 'same' , activation = 'relu'))
model.add(BatchNormalization())
model.add(MaxPool2D((2,2) , strides = 2 , padding = 'same'))
model.add(Conv2D(128 , (3,3) , strides = 1 , padding = 'same' , activation = 'relu'))
model.add(Dropout(0.2))
model.add(BatchNormalization())
model.add(MaxPool2D((2,2) , strides = 2 , padding = 'same'))
model.add(Conv2D(256 , (3,3) , strides = 1 , padding = 'same' , activation = 'relu'))
model.add(Dropout(0.2))
model.add(BatchNormalization())
model.add(MaxPool2D((2,2) , strides = 2 , padding = 'same'))
model.add(Flatten())
model.add(Dense(units = 128 , activation = 'relu'))
model.add(Dropout(0.2))
model.add(Dense(units = 1 , activation = 'sigmoid'))
model.compile(optimizer = "rmsprop" , loss = 'binary_crossentropy' , metrics = ['accuracy',
    tf.keras.metrics.Precision(name='precision'),
    tf.keras.metrics.Recall(name='recall')])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 150, 150, 32)      320
#
#  batch_normalization (BatchN  (None, 150, 150, 32)     128
#  ormalization)
#
#  max_pooling2d (MaxPooling2D  (None, 75, 75, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 75, 75, 64)        18496
#
#  dropout (Dropout)           (None, 75, 75, 64)        0
#
#  batch_normalization_1 (Batc  (None, 75, 75, 64)       256
#  hNormalization)
#
#  max_pooling2d_1 (MaxPooling  (None, 38, 38, 64)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 38, 38, 64)        36928
#
#  batch_normalization_2 (Batc  (None, 38, 38, 64)       256
#  hNormalization)
#
#  max_pooling2d_2 (MaxPooling  (None, 19, 19, 64)       0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 19, 19, 128)       73856
#
#  dropout_1 (Dropout)         (None, 19, 19, 128)       0
#
#  batch_normalization_3 (Batc  (None, 19, 19, 128)      512
#  hNormalization)
#
#  max_pooling2d_3 (MaxPooling  (None, 10, 10, 128)      0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 10, 10, 256)       295168
#
#  dropout_2 (Dropout)         (None, 10, 10, 256)       0
#
#  batch_normalization_4 (Batc  (None, 10, 10, 256)      1024
#  hNormalization)
#
#  max_pooling2d_4 (MaxPooling  (None, 5, 5, 256)        0
#  2D)
#
#  flatten (Flatten)           (None, 6400)              0
#
#  dense (Dense)               (None, 128)               819328
#
#  dropout_3 (Dropout)         (None, 128)               0
#
#  dense_1 (Dense)             (None, 1)                 129
#
# =================================================================
# Total params: 1,246,401
# Trainable params: 1,245,313
# Non-trainable params: 1,088
# _________________________________________________________________

# %%
# Lo vemos en forma gráfica
plot_model(model, show_shapes=True, show_layer_names=True)

# %% [markdown]
# ### 5.2. Entrenamiento
#
# Se realiza el entrenamiento de la CNN con el set de train, test y validación definidos anteriormente.

# %%
# Seteo de los hiper-parámetros
AUTOTUNE = tf.data.experimental.AUTOTUNE
BATCH_SIZE = 32
IMAGE_SIZE = [img_size, img_size]
EPOCHS = 100

# %%
# Definición de callbacks
checkpoint_callback = tf.keras.callbacks.ModelCheckpoint("pneumonia_model.h5", save_best_only=True)

# Saco temp que queda bajo
early_stopping_callback = tf.keras.callbacks.EarlyStopping(patience=20, restore_best_weights=True)

# %%
def exponential_decay(lr0, s):
    def exponential_decay_fn(epoch):
        return lr0 * 0.1 **(epoch / s)
    return exponential_decay_fn

exponential_decay_fn = exponential_decay(0.01, 20)
learning_rate_reduction = tf.keras.callbacks.LearningRateScheduler(exponential_decay_fn)

# %%
# Entrenamos la red
history = model.fit(
    datagen.flow(x_train, y_train, batch_size = BATCH_SIZE),
    epochs=EPOCHS,
    validation_data=datagen.flow(x_val, y_val),
    class_weight=class_weight,
    callbacks = [checkpoint_callback, learning_rate_reduction, early_stopping_callback]
)
# Out:
# Epoch 1/100
# 132/132 [==============================] - 32s 232ms/step - loss: 3.2658 - accuracy: 0.6005 - precision: 0.8812 - recall: 0.5257 - val_loss: 1.0526 - val_accuracy: 0.7143 - val_precision: 0.7177 - val_recall: 0.9911 - lr: 0.0100
# Epoch 2/100
# 132/132 [==============================] - 32s 240ms/step - loss: 0.5371 - accuracy: 0.7298 - precision: 0.9235 - recall: 0.6882 - val_loss: 0.4520 - val_accuracy: 0.7484 - val_precision: 0.7412 - val_recall: 0.9970 - lr: 0.0089
# Epoch 3/100
# 132/132 [==============================] - 31s 236ms/step - loss: 0.3661 - accuracy: 0.7924 - precision: 0.9518 - recall: 0.7549 - val_loss: 8.0136 - val_accuracy: 0.7186 - val_precision: 0.7179 - val_recall: 1.0000 - lr: 0.0079
# Epoch 4/100
# 132/132 [==============================] - 31s 235ms/step - loss: 0.4050 - accuracy: 0.8306 - precision: 0.9510 - recall: 0.8106 - val_loss: 4.5914 - val_accuracy: 0.7164 - val_precision: 0.7164 - val_recall: 1.0000 - lr: 0.0071
# Epoch 5/100
# 132/132 [==============================] - 31s 233ms/step - loss: 0.2798 - accuracy: 0.8664 - precision: 0.9573 - recall: 0.8559 - val_loss: 19.8401 - val_accuracy: 0.7164 - val_precision: 0.7164 - val_recall: 1.0000 - lr: 0.0063
# Epoch 6/100
# 132/132 [==============================] - 31s 234ms/step - loss: 0.2361 - accuracy: 0.8864 - precision: 0.9615 - recall: 0.8802 - val_loss: 2.8788 - val_accuracy: 0.8188 - val_precision: 0.8010 - val_recall: 0.9940 - lr: 0.0056
# Epoch 7/100
# 132/132 [==============================] - 31s 234ms/step - loss: 0.2454 - accuracy: 0.8944 - precision: 0.9665 - recall: 0.8867 - val_loss: 0.2395 - val_accuracy: 0.9168 - val_precision: 0.9655 - val_recall: 0.9167 - lr: 0.0050
# Epoch 8/100
# 132/132 [==============================] - 31s 235ms/step - loss: 0.2201 - accuracy: 0.9044 - precision: 0.9628 - recall: 0.9045 - val_loss: 1.3890 - val_accuracy: 0.8422 - val_precision: 0.8342 - val_recall: 0.9732 - lr: 0.0045
# Epoch 9/100
# 132/132 [==============================] - 31s 232ms/step - loss: 0.2082 - accuracy: 0.9094 - precision: 0.9634 - recall: 0.9110 - val_loss: 11.4676 - val_accuracy: 0.7164 - val_precision: 0.7164 - val_recall: 1.0000 - lr: 0.0040
# Epoch 10/100
# 132/132 [==============================] - 31s 231ms/step - loss: 0.1933 - accuracy: 0.9193 - precision: 0.9645 - recall: 0.9239 - val_loss: 0.3701 - val_accuracy: 0.8827 - val_precision: 0.8767 - val_recall: 0.9732 - lr: 0.0035
# Epoch 11/100
# 132/132 [==============================] - 31s 235ms/step - loss: 0.1941 - accuracy: 0.9231 - precision: 0.9707 - recall: 0.9230 - val_loss: 0.1918 - val_accuracy: 0.9275 - val_precision: 0.9415 - val_recall: 0.9583 - lr: 0.0032
# Epoch 12/100
# 132/132 [==============================] - 31s 233ms/step - loss: 0.1710 - accuracy: 0.9269 - precision: 0.9696 - recall: 0.9294 - val_loss: 2.1627 - val_accuracy: 0.8721 - val_precision: 0.8520 - val_recall: 0.9940 - lr: 0.0028
# Epoch 13/100
# 132/132 [==============================] - 31s 232ms/step - loss: 0.1728 - accuracy: 0.9255 - precision: 0.9695 - recall: 0.9275 - val_loss: 0.9265 - val_accuracy: 0.7953 - val_precision: 0.7778 - val_recall: 1.0000 - lr: 0.0025
# Epoch 14/100
# 132/132 [==============================] - 31s 237ms/step - loss: 0.1546 - accuracy: 0.9300 - precision: 0.9716 - recall: 0.9317 - val_loss: 3.2234 - val_accuracy: 0.8102 - val_precision: 0.7906 - val_recall: 1.0000 - lr: 0.0022
# Epoch 15/100
# 132/132 [==============================] - 32s 240ms/step - loss: 0.1598 - accuracy: 0.9352 - precision: 0.9731 - recall: 0.9375 - val_loss: 0.8144 - val_accuracy: 0.8380 - val_precision: 0.8202 - val_recall: 0.9911 - lr: 0.0020
# Epoch 16/100
# 132/132 [==============================] - 30s 231ms/step - loss: 0.1553 - accuracy: 0.9336 - precision: 0.9727 - recall: 0.9356 - val_loss: 0.4452 - val_accuracy: 0.8742 - val_precision: 0.8579 - val_recall: 0.9881 - lr: 0.0018
# Epoch 17/100
# 132/132 [==============================] - 30s 231ms/step - loss: 0.1494 - accuracy: 0.9338 - precision: 0.9734 - recall: 0.9353 - val_loss: 0.1853 - val_accuracy: 0.9382 - val_precision: 0.9528 - val_recall: 0.9613 - lr: 0.0016
# Epoch 18/100
# 132/132 [==============================] - 31s 233ms/step - loss: 0.1466 - accuracy: 0.9397 - precision: 0.9758 - recall: 0.9411 - val_loss: 1.4517 - val_accuracy: 0.8358 - val_precision: 0.8166 - val_recall: 0.9940 - lr: 0.0014
# Epoch 19/100
# 132/132 [==============================] - 31s 233ms/step - loss: 0.1326 - accuracy: 0.9421 - precision: 0.9759 - recall: 0.9443 - val_loss: 0.1715 - val_accuracy: 0.9488 - val_precision: 0.9615 - val_recall: 0.9673 - lr: 0.0013
# Epoch 20/100
# 132/132 [==============================] - 31s 237ms/step - loss: 0.1439 - accuracy: 0.9414 - precision: 0.9772 - recall: 0.9421 - val_loss: 1.8830 - val_accuracy: 0.7953 - val_precision: 0.7804 - val_recall: 0.9940 - lr: 0.0011
# Epoch 21/100
# 132/132 [==============================] - 30s 230ms/step - loss: 0.1358 - accuracy: 0.9438 - precision: 0.9779 - recall: 0.9446 - val_loss: 0.2371 - val_accuracy: 0.9360 - val_precision: 0.9500 - val_recall: 0.9613 - lr: 0.0010
# Epoch 22/100
# 132/132 [==============================] - 31s 232ms/step - loss: 0.1239 - accuracy: 0.9516 - precision: 0.9794 - recall: 0.9540 - val_loss: 0.1657 - val_accuracy: 0.9424 - val_precision: 0.9558 - val_recall: 0.9643 - lr: 8.9125e-04
# Epoch 23/100
# 132/132 [==============================] - 31s 233ms/step - loss: 0.1160 - accuracy: 0.9483 - precision: 0.9796 - recall: 0.9492 - val_loss: 0.1878 - val_accuracy: 0.9296 - val_precision: 0.9605 - val_recall: 0.9405 - lr: 7.9433e-04
# Epoch 24/100
# 132/132 [==============================] - 31s 233ms/step - loss: 0.1333 - accuracy: 0.9459 - precision: 0.9760 - recall: 0.9495 - val_loss: 0.1444 - val_accuracy: 0.9574 - val_precision: 0.9731 - val_recall: 0.9673 - lr: 7.0795e-04
# Epoch 25/100
# 132/132 [==============================] - 31s 232ms/step - loss: 0.1225 - accuracy: 0.9466 - precision: 0.9786 - recall: 0.9479 - val_loss: 0.2260 - val_accuracy: 0.9019 - val_precision: 0.8898 - val_recall: 0.9851 - lr: 6.3096e-04
# Epoch 26/100
# 132/132 [==============================] - 31s 234ms/step - loss: 0.1177 - accuracy: 0.9521 - precision: 0.9794 - recall: 0.9547 - val_loss: 0.1487 - val_accuracy: 0.9552 - val_precision: 0.9539 - val_recall: 0.9851 - lr: 5.6234e-04
# Epoch 27/100
# 132/132 [==============================] - 31s 232ms/step - loss: 0.1192 - accuracy: 0.9530 - precision: 0.9801 - recall: 0.9553 - val_loss: 0.1689 - val_accuracy: 0.9424 - val_precision: 0.9813 - val_recall: 0.9375 - lr: 5.0119e-04
# Epoch 28/100
# 132/132 [==============================] - 31s 233ms/step - loss: 0.1085 - accuracy: 0.9544 - precision: 0.9808 - recall: 0.9566 - val_loss: 0.2547 - val_accuracy: 0.9062 - val_precision: 0.8904 - val_recall: 0.9911 - lr: 4.4668e-04
# Epoch 29/100
# 132/132 [==============================] - 31s 235ms/step - loss: 0.1132 - accuracy: 0.9483 - precision: 0.9787 - recall: 0.9501 - val_loss: 0.2203 - val_accuracy: 0.9232 - val_precision: 0.9747 - val_recall: 0.9167 - lr: 3.9811e-04
# Epoch 30/100
# 132/132 [==============================] - 31s 234ms/step - loss: 0.1240 - accuracy: 0.9540 - precision: 0.9801 - recall: 0.9566 - val_loss: 0.1558 - val_accuracy: 0.9382 - val_precision: 0.9424 - val_recall: 0.9732 - lr: 3.5481e-04
# Epoch 31/100
# 132/132 [==============================] - 31s 235ms/step - loss: 0.1116 - accuracy: 0.9537 - precision: 0.9814 - recall: 0.9550 - val_loss: 0.1369 - val_accuracy: 0.9467 - val_precision: 0.9587 - val_recall: 0.9673 - lr: 3.1623e-04
# Epoch 32/100
# 132/132 [==============================] - 32s 245ms/step - loss: 0.1130 - accuracy: 0.9542 - precision: 0.9807 - recall: 0.9563 - val_loss: 0.1458 - val_accuracy: 0.9467 - val_precision: 0.9405 - val_recall: 0.9881 - lr: 2.8184e-04
# Epoch 33/100
# 132/132 [==============================] - 31s 233ms/step - loss: 0.1020 - accuracy: 0.9573 - precision: 0.9815 - recall: 0.9599 - val_loss: 0.1552 - val_accuracy: 0.9360 - val_precision: 0.9527 - val_recall: 0.9583 - lr: 2.5119e-04
# Epoch 34/100
# 132/132 [==============================] - 29s 221ms/step - loss: 0.1089 - accuracy: 0.9535 - precision: 0.9788 - recall: 0.9573 - val_loss: 0.1995 - val_accuracy: 0.9275 - val_precision: 0.9218 - val_recall: 0.9821 - lr: 2.2387e-04
# Epoch 35/100
# 132/132 [==============================] - 30s 223ms/step - loss: 0.0987 - accuracy: 0.9563 - precision: 0.9811 - recall: 0.9589 - val_loss: 0.1333 - val_accuracy: 0.9424 - val_precision: 0.9452 - val_recall: 0.9762 - lr: 1.9953e-04
# Epoch 36/100
# 132/132 [==============================] - 29s 222ms/step - loss: 0.1223 - accuracy: 0.9556 - precision: 0.9824 - recall: 0.9566 - val_loss: 0.1456 - val_accuracy: 0.9467 - val_precision: 0.9560 - val_recall: 0.9702 - lr: 1.7783e-04
# Epoch 37/100
# 132/132 [==============================] - 30s 224ms/step - loss: 0.1020 - accuracy: 0.9580 - precision: 0.9834 - recall: 0.9589 - val_loss: 0.1747 - val_accuracy: 0.9424 - val_precision: 0.9668 - val_recall: 0.9524 - lr: 1.5849e-04
# Epoch 38/100
# 132/132 [==============================] - 30s 223ms/step - loss: 0.1022 - accuracy: 0.9599 - precision: 0.9822 - recall: 0.9628 - val_loss: 0.1634 - val_accuracy: 0.9382 - val_precision: 0.9501 - val_recall: 0.9643 - lr: 1.4125e-04
# Epoch 39/100
# 132/132 [==============================] - 30s 224ms/step - loss: 0.1059 - accuracy: 0.9549 - precision: 0.9808 - recall: 0.9573 - val_loss: 0.1527 - val_accuracy: 0.9488 - val_precision: 0.9457 - val_recall: 0.9851 - lr: 1.2589e-04
# Epoch 40/100
# 132/132 [==============================] - 30s 224ms/step - loss: 0.1013 - accuracy: 0.9554 - precision: 0.9814 - recall: 0.9573 - val_loss: 0.1423 - val_accuracy: 0.9574 - val_precision: 0.9514 - val_recall: 0.9911 - lr: 1.1220e-04
# Epoch 41/100
# 132/132 [==============================] - 30s 225ms/step - loss: 0.1052 - accuracy: 0.9582 - precision: 0.9824 - recall: 0.9602 - val_loss: 0.1851 - val_accuracy: 0.9360 - val_precision: 0.9250 - val_recall: 0.9911 - lr: 1.0000e-04
# Epoch 42/100
# 132/132 [==============================] - 30s 228ms/step - loss: 0.0996 - accuracy: 0.9580 - precision: 0.9818 - recall: 0.9605 - val_loss: 0.1656 - val_accuracy: 0.9318 - val_precision: 0.9318 - val_recall: 0.9762 - lr: 8.9125e-05
# Epoch 43/100
# 132/132 [==============================] - 31s 231ms/step - loss: 0.1062 - accuracy: 0.9556 - precision: 0.9814 - recall: 0.9576 - val_loss: 0.1590 - val_accuracy: 0.9275 - val_precision: 0.9290 - val_recall: 0.9732 - lr: 7.9433e-05
# Epoch 44/100
# 132/132 [==============================] - 30s 227ms/step - loss: 0.0874 - accuracy: 0.9599 - precision: 0.9847 - recall: 0.9602 - val_loss: 0.1286 - val_accuracy: 0.9467 - val_precision: 0.9534 - val_recall: 0.9732 - lr: 7.0795e-05
# Epoch 45/100
# 132/132 [==============================] - 30s 228ms/step - loss: 0.0912 - accuracy: 0.9628 - precision: 0.9848 - recall: 0.9641 - val_loss: 0.1284 - val_accuracy: 0.9467 - val_precision: 0.9560 - val_recall: 0.9702 - lr: 6.3096e-05
# Epoch 46/100
# 132/132 [==============================] - 30s 226ms/step - loss: 0.1094 - accuracy: 0.9568 - precision: 0.9811 - recall: 0.9595 - val_loss: 0.1569 - val_accuracy: 0.9339 - val_precision: 0.9499 - val_recall: 0.9583 - lr: 5.6234e-05
# Epoch 47/100
# 132/132 [==============================] - 30s 224ms/step - loss: 0.1043 - accuracy: 0.9556 - precision: 0.9837 - recall: 0.9553 - val_loss: 0.1275 - val_accuracy: 0.9510 - val_precision: 0.9484 - val_recall: 0.9851 - lr: 5.0119e-05
# Epoch 48/100
# 132/132 [==============================] - 30s 226ms/step - loss: 0.0987 - accuracy: 0.9540 - precision: 0.9807 - recall: 0.9560 - val_loss: 0.1243 - val_accuracy: 0.9424 - val_precision: 0.9452 - val_recall: 0.9762 - lr: 4.4668e-05
# Epoch 49/100
# 132/132 [==============================] - 30s 225ms/step - loss: 0.0921 - accuracy: 0.9597 - precision: 0.9844 - recall: 0.9602 - val_loss: 0.1286 - val_accuracy: 0.9531 - val_precision: 0.9511 - val_recall: 0.9851 - lr: 3.9811e-05
# Epoch 50/100
# 132/132 [==============================] - 30s 226ms/step - loss: 0.0867 - accuracy: 0.9597 - precision: 0.9825 - recall: 0.9621 - val_loss: 0.1372 - val_accuracy: 0.9424 - val_precision: 0.9427 - val_recall: 0.9792 - lr: 3.5481e-05
# Epoch 51/100
# 132/132 [==============================] - 30s 225ms/step - loss: 0.0886 - accuracy: 0.9599 - precision: 0.9841 - recall: 0.9608 - val_loss: 0.1419 - val_accuracy: 0.9510 - val_precision: 0.9563 - val_recall: 0.9762 - lr: 3.1623e-05
# Epoch 52/100
# 132/132 [==============================] - 30s 223ms/step - loss: 0.0964 - accuracy: 0.9601 - precision: 0.9809 - recall: 0.9644 - val_loss: 0.1449 - val_accuracy: 0.9488 - val_precision: 0.9671 - val_recall: 0.9613 - lr: 2.8184e-05
# Epoch 53/100
# 132/132 [==============================] - 30s 224ms/step - loss: 0.0887 - accuracy: 0.9625 - precision: 0.9854 - recall: 0.9631 - val_loss: 0.1174 - val_accuracy: 0.9638 - val_precision: 0.9623 - val_recall: 0.9881 - lr: 2.5119e-05
# Epoch 54/100
# 132/132 [==============================] - 30s 227ms/step - loss: 0.0925 - accuracy: 0.9604 - precision: 0.9825 - recall: 0.9631 - val_loss: 0.1401 - val_accuracy: 0.9488 - val_precision: 0.9588 - val_recall: 0.9702 - lr: 2.2387e-05
# Epoch 55/100
# 132/132 [==============================] - 31s 232ms/step - loss: 0.0902 - accuracy: 0.9592 - precision: 0.9815 - recall: 0.9624 - val_loss: 0.1495 - val_accuracy: 0.9467 - val_precision: 0.9560 - val_recall: 0.9702 - lr: 1.9953e-05
# Epoch 56/100
# 132/132 [==============================] - 31s 233ms/step - loss: 0.1019 - accuracy: 0.9609 - precision: 0.9844 - recall: 0.9618 - val_loss: 0.1522 - val_accuracy: 0.9424 - val_precision: 0.9427 - val_recall: 0.9792 - lr: 1.7783e-05
# Epoch 57/100
# 132/132 [==============================] - 31s 232ms/step - loss: 0.0910 - accuracy: 0.9623 - precision: 0.9857 - recall: 0.9624 - val_loss: 0.1536 - val_accuracy: 0.9446 - val_precision: 0.9429 - val_recall: 0.9821 - lr: 1.5849e-05
# Epoch 58/100
# 132/132 [==============================] - 31s 234ms/step - loss: 0.0894 - accuracy: 0.9628 - precision: 0.9851 - recall: 0.9637 - val_loss: 0.1588 - val_accuracy: 0.9446 - val_precision: 0.9429 - val_recall: 0.9821 - lr: 1.4125e-05
# Epoch 59/100
# 132/132 [==============================] - 31s 231ms/step - loss: 0.0916 - accuracy: 0.9604 - precision: 0.9825 - recall: 0.9631 - val_loss: 0.1357 - val_accuracy: 0.9488 - val_precision: 0.9483 - val_recall: 0.9821 - lr: 1.2589e-05
# Epoch 60/100
# 132/132 [==============================] - 30s 224ms/step - loss: 0.0851 - accuracy: 0.9635 - precision: 0.9842 - recall: 0.9657 - val_loss: 0.1416 - val_accuracy: 0.9531 - val_precision: 0.9564 - val_recall: 0.9792 - lr: 1.1220e-05
# Epoch 61/100
# 132/132 [==============================] - 30s 226ms/step - loss: 0.0907 - accuracy: 0.9575 - precision: 0.9860 - recall: 0.9556 - val_loss: 0.1540 - val_accuracy: 0.9360 - val_precision: 0.9448 - val_recall: 0.9673 - lr: 1.0000e-05
# Epoch 62/100
# 132/132 [==============================] - 31s 233ms/step - loss: 0.0937 - accuracy: 0.9609 - precision: 0.9825 - recall: 0.9637 - val_loss: 0.1421 - val_accuracy: 0.9424 - val_precision: 0.9478 - val_recall: 0.9732 - lr: 8.9125e-06
# Epoch 63/100
# 132/132 [==============================] - 31s 235ms/step - loss: 0.0955 - accuracy: 0.9604 - precision: 0.9828 - recall: 0.9628 - val_loss: 0.1400 - val_accuracy: 0.9446 - val_precision: 0.9506 - val_recall: 0.9732 - lr: 7.9433e-06
# Epoch 64/100
# 132/132 [==============================] - 29s 223ms/step - loss: 0.0865 - accuracy: 0.9628 - precision: 0.9829 - recall: 0.9660 - val_loss: 0.1264 - val_accuracy: 0.9510 - val_precision: 0.9510 - val_recall: 0.9821 - lr: 7.0795e-06
# Epoch 65/100
# 132/132 [==============================] - 32s 239ms/step - loss: 0.0879 - accuracy: 0.9611 - precision: 0.9819 - recall: 0.9647 - val_loss: 0.1498 - val_accuracy: 0.9446 - val_precision: 0.9480 - val_recall: 0.9762 - lr: 6.3096e-06
# Epoch 66/100
# 132/132 [==============================] - 31s 234ms/step - loss: 0.0938 - accuracy: 0.9644 - precision: 0.9851 - recall: 0.9660 - val_loss: 0.1306 - val_accuracy: 0.9552 - val_precision: 0.9619 - val_recall: 0.9762 - lr: 5.6234e-06
# Epoch 67/100
# 132/132 [==============================] - 29s 222ms/step - loss: 0.0917 - accuracy: 0.9637 - precision: 0.9845 - recall: 0.9657 - val_loss: 0.1261 - val_accuracy: 0.9446 - val_precision: 0.9480 - val_recall: 0.9762 - lr: 5.0119e-06
# Epoch 68/100
# 132/132 [==============================] - 29s 222ms/step - loss: 0.0910 - accuracy: 0.9613 - precision: 0.9816 - recall: 0.9654 - val_loss: 0.1572 - val_accuracy: 0.9360 - val_precision: 0.9448 - val_recall: 0.9673 - lr: 4.4668e-06
# Epoch 69/100
# 132/132 [==============================] - 29s 222ms/step - loss: 0.0954 - accuracy: 0.9592 - precision: 0.9806 - recall: 0.9634 - val_loss: 0.1473 - val_accuracy: 0.9382 - val_precision: 0.9424 - val_recall: 0.9732 - lr: 3.9811e-06
# Epoch 70/100
# 132/132 [==============================] - 29s 222ms/step - loss: 0.0904 - accuracy: 0.9606 - precision: 0.9812 - recall: 0.9647 - val_loss: 0.1358 - val_accuracy: 0.9531 - val_precision: 0.9538 - val_recall: 0.9821 - lr: 3.5481e-06
# Epoch 71/100
# 132/132 [==============================] - 30s 225ms/step - loss: 0.0976 - accuracy: 0.9578 - precision: 0.9844 - recall: 0.9576 - val_loss: 0.1245 - val_accuracy: 0.9510 - val_precision: 0.9484 - val_recall: 0.9851 - lr: 3.1623e-06
# Epoch 72/100
# 132/132 [==============================] - 32s 240ms/step - loss: 0.0955 - accuracy: 0.9592 - precision: 0.9825 - recall: 0.9615 - val_loss: 0.1552 - val_accuracy: 0.9510 - val_precision: 0.9484 - val_recall: 0.9851 - lr: 2.8184e-06
# Epoch 73/100
# 132/132 [==============================] - 30s 225ms/step - loss: 0.0948 - accuracy: 0.9599 - precision: 0.9822 - recall: 0.9628 - val_loss: 0.1654 - val_accuracy: 0.9318 - val_precision: 0.9368 - val_recall: 0.9702 - lr: 2.5119e-06

# %% [markdown]
# ## 6. Validación y análisis de resultados
#
# En esta sección evaluamos los resultados obtenidos.

# %% [markdown]
# ### 6.1. Performance obtenida
#
# Graficamos asimismo las cuatro métricas calculadas durante el entrenamiento. Imprimimos las dos métricas principales, loss y accuracy para el entrenamiento y validación.

# %%
# Graficamos las métricas obtenidas
fig, ax = plt.subplots(1, 4, figsize=(20, 3))
ax = ax.ravel()

for i, met in enumerate(['precision', 'recall', 'accuracy', 'loss']):
    ax[i].plot(history.history[met])
    ax[i].plot(history.history['val_' + met])
    ax[i].set_title('Model {}'.format(met))
    ax[i].set_xlabel('epochs')
    ax[i].set_ylabel(met)
    ax[i].legend(['train', 'val'])

# %% [markdown]
# ### 6.2. Predicción de nuevas imágenes
#
# Una vez entrenado el modelo, hacemos la predicción del set de test, e imprimimos los resultados de loss y accuracy para la prueba realizada.

# %%
# Mostramos las métricas de loss y accuracy
test_scores = model.evaluate(x_test,y_test)
print("Loss de modelo - " + str(round(test_scores[0], 2)))
print("Accuracy del modelo - " + str(round(test_scores[1]*100, 2)) + "%")
# Out:
# 37/37 [==============================] - 2s 50ms/step - loss: 0.1571 - accuracy: 0.9505 - precision: 0.9794 - recall: 0.9517
# Loss de modelo - 0.16
# Accuracy del modelo - 95.05%

# %% [markdown]
# ### 6.3. Reporte de clasificación y matriz de confusión
#
# Analizamos en esta sección cómo ha clasificado la red, tanto en términos de clasificaciones correctas como incorrectas.

# %%
# Calculamos el reporte de clasificación
predictions = (model.predict(x_test) > 0.5).astype("int32")
predictions = predictions.reshape(1,-1)[0]

print(classification_report(y_test, predictions, target_names = ['Normal (Class 0)', 'Pneumonia (Class 1)']))
# Out:
#                      precision    recall  f1-score   support
#
#    Normal (Class 0)       0.88      0.95      0.91       324
# Pneumonia (Class 1)       0.98      0.95      0.97       848
#
#            accuracy                           0.95      1172
#           macro avg       0.93      0.95      0.94      1172
#        weighted avg       0.95      0.95      0.95      1172

# %%
# Calculamos la matriz de confusión
cm = confusion_matrix(y_test, predictions)
cm = pd.DataFrame(cm , index = ['0','1'] , columns = ['0','1'])

plt.figure(figsize = (7,7))
sns.set(font_scale=1.4)
sns.heatmap(cm,cmap= "Blues", linecolor = 'black', linewidth = 1, annot = True, fmt='', xticklabels = labels, yticklabels = labels)
# Out:
# <AxesSubplot: >

# %% [markdown]
# ### 6.4. Ejemplos de casos mal clasificados
#
# A fin de poder visualizar mejor los casos mal clasificados, se muestran algunos ejemplos. Sería interesante contar con una opinión experta que permita discernir si se trata de casos de borde o la red ha clasificado mal casos obvios, como para entender mejor el comportamiento obtenido para estos casos.

# %%
# Mostramos algunos de los casos mal clasificados
incorrect = np.nonzero(predictions != y_test)[0]
fig, axs = plt.subplots(3, 3, figsize=(15, 15))
for i in range(3):
    for j in range(3):
        axs[i, j].set_yticks([])
        axs[i, j].set_xticks([])
        axs[i, j].imshow(x_test[incorrect[3*i+j]].reshape(150,150), cmap="gray", interpolation='none')
        axs[i, j].set_title("Clasificó clase {}, clase real {}".format(predictions[incorrect[3*i+j]], y_test[incorrect[3*i+j]]))
